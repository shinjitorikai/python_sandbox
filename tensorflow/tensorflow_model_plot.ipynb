# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import random
import os

import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# %%
# TensorFlow Version
tf.__version__

# %%
# model
model = tf.keras.applications.EfficientNetV2L(
    include_top=True,
    weights=None,
    input_shape=(224,224,3),
    classes=2
)

# %%
if True:
    model.summary()

if False:
    with open(os.path.join('model.txt'),mode='w') as fw:
        model.summary(print_fn=lambda x: fw.write(x+'\n'))

if False:
    _ = tf.keras.utils.plot_model(model,to_file='model.png',show_shapes=True,show_layer_activations=True)
